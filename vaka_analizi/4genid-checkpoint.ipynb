# %%
import pandas as pd
import numpy as np

# %%
significant_genes = pd.read_csv("significant_genes.csv", index_col=0)
significant_genes
# Out:
#                   p_value  significantly_changed
# converted_alias
# ENSG00000284662  0.009101                   True
# ENSG00000291156  0.013085                   True
# ENSG00000248333  0.036266                   True
# ENSG00000169598  0.009468                   True
# ENSG00000236423  0.036745                   True
# ...                   ...                    ...
# ENSG00000183837  0.006490                   True
# ENSG00000102030  0.025413                   True
# ENSG00000207165  0.033273                   True
# ENSG00000071859  0.006995                   True
# ENSG00000182712  0.024904                   True
#
# [2071 rows x 2 columns]

# %%
converter = pd.read_csv("converter.csv", index_col=0, sep=',')
converter
# Out:
#                converted_alias       name  \
# initial_alias
# 100287102      ENSG00000290825    DDX11L2
# 653635                     NaN        NaN
# 102466751      ENSG00000278267  MIR6859-1
# 107985730                  NaN        NaN
# 100302278      ENSG00000284332  MIR1302-2
# ...                        ...        ...
# 4541           ENSG00000198695     MT-ND6
# 4556                       NaN        NaN
# 4519           ENSG00000198727     MT-CYB
# 4576                       NaN        NaN
# 4571                       NaN        NaN
#
#                                                      description  \
# initial_alias
# 100287102      DEAD/H-box helicase 11 like 2 (pseudogene) [So...
# 653635                                                       NaN
# 102466751      microRNA 6859-1 [Source:HGNC Symbol;Acc:HGNC:5...
# 107985730                                                    NaN
# 100302278      microRNA 1302-2 [Source:HGNC Symbol;Acc:HGNC:3...
# ...

# %%
merged_data = pd.merge(significant_genes, converter, left_on='converted_alias', right_on='initial_alias', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1884\3281487074.py in ?()
# ----> 1 merged_data = pd.merge(significant_genes, converter, left_on='converted_alias', right_on='Ensembl_ID', how='left')
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
# ...
